# %%
# !pip list
# Out:
# Package                            Version
# ---------------------------------- -----------
# alembic                            1.14.1
# anyio                              4.5.2
# argon2-cffi                        25.1.0
# argon2-cffi-bindings               21.2.0
# asttokens                          3.0.1
# async-lru                          2.0.4
# attrs                              25.3.0
# babel                              2.17.0
# backcall                           0.2.0
# beautifulsoup4                     4.14.3
# bleach                             6.1.0
# blinker                            1.8.2
# cachetools                         5.5.2
# certifi                            2025.11.12
# cffi                               1.17.1
# charset-normalizer                 3.4.4
# click                              8.1.8
# cloudpickle                        3.1.2
# comm                               0.2.3
# contourpy                          1.1.1
# ...

# %%
import pandas as pd
pd.__version__
# Out:
# '2.0.3'
